# %%
import pyclf
from pyclf.discriminant_analysis import BinaryLinearDiscriminantAnalysis
from pyclf.datasets import generate_2d_multiclass_data
from pyclf.viz import plot_train_test_scatter

mus = [
    [-1.0, -1.0],
    [1.0, 1.0],
]

covs = [
    0.1,
    0.1,
]

n_train = [500, 500]
n_test  = [100,  100]

X_train, y_train, X_test, y_test = generate_2d_multiclass_data(
    mus, covs, n_train, n_test, random_state=42
)

plot_train_test_scatter(X_train, y_train, X_test, y_test)

model = BinaryLinearDiscriminantAnalysis()

model.fit(X_train, y_train)
# Out:
# (2,)
# 2
# 1000
# [-0.018041   -0.01723704]
# [-5.36348743e-16  2.35478304e-16]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      23 plot_train_test_scatter(X_train, y_train, X_test, y_test)
#      25 model = BinaryLinearDiscriminantAnalysis()
# ---> 27 model.fit(X_train, y_train)
#
# File ~\git\pyclf\pyclf\discriminant_analysis.py:89, in BinaryLinearDiscriminantAnalysis.fit(self, X, y)
#      86 print(X.mean(0))
#      87 print(Xc.mean(0))
# ---> 89 exit()
#      91 Sigma = (Xw.T @ Xw) / (n_samples - self.ddof)
#      93 print()
#
# NameError: name 'exit' is not defined
